# %% [markdown]
# #### For this problem set I worked with Eugene Leypunskiy

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
import string
from collections import Counter
import nltk
from nltk.corpus import stopwords
from itertools import permutations, product
import os
import cPickle
import scipy

# %% [markdown]
# ### PMI Embeddings

# %%
wiki_file = open('/project/cmsc25025/wikipedia/wiki-text.txt','r').readlines()[0]
num_chunks = 28**3 #make it multiple of number of your cores
chunks, chunk_size = len(wiki_file), len(wiki_file)/num_chunks
wiki_chunks = [wiki_file[i:i+chunk_size] for i in range(0, chunks, chunk_size)]

spark = SparkSession.builder.master('local[*]')\
                            .appName('wiki')\
                            .config("spark.driver.maxResultSize", "20g")\
                            .config("spark.driver.memory", "20g")\
                            .config("spark.executor.memory", "20g")\
                            .getOrCreate()

wiki_data = spark.sparkContext.parallelize(wiki_chunks)

# %%
stopWords = set(stopwords.words('english'))
stopWords = [i for i in stopWords]

# %%
def get_rid_of_stopwords(countVar, stopWords):
    for i in stopWords:
        try:
            countVar.pop(i)
        except KeyError:
            continue
    return countVar

# %%
vocabulary = wiki_data.map(lambda x: x.split())\
                      .map(lambda x: Counter(x))\
                      .map(lambda x: get_rid_of_stopwords(x, stopWords))\
                      .reduce(lambda a,b: a + b)

# %%
vocabulary = Counter({k:v for k,v in vocabulary.items() if v > 500}).most_common()

# %%
masterVocabs, masterVocabCounts = zip(*vocabulary)
masterVocabs = list(masterVocabs)
masterVocabCounts = list(masterVocabCounts)

# %%
def make_word_context_tuples(text, masterVocabs):
    wordContextList = []
    for i,item in enumerate(text):
        for j in range(11):
            j = j - 5
            index = i + j
            if j == 0:
                continue
            if index < 0:
                continue
            else:                
                try:
                    if item not in masterVocabs:
                        continue
                    elif text[index] not in masterVocabs:
                        continue
                    wordContext = ((item,text[index]),1)
                    wordContextList.append(wordContext)
                except IndexError:
                    continue
    return wordContextList

# %% [markdown]
# ### Part (a): calculating co-occurrance w-c pairs

# %%
co_occurance = wiki_data.map(lambda x: x.split())\
                        .flatMap(lambda x: make_word_context_tuples(x, masterVocabs))\
                        .reduceByKey(lambda a,b: a + b)

# %%
# This takes a long time

coOccuranceVector = co_occurance.collect()

# %%
# So let's save the vector
cPickle.dump(coOccuranceVector, open("coOccuranceVector.cp", "wb"))

# %%
coOccuranceCardinality = len(coOccuranceVector)
coOccuranceDict = dict(coOccuranceVector)

# %%
# Calculating the PMI matrix
pmiMatrix = []
for i, vocab1 in enumerate(masterVocabs):
    dumList1 = []
    for j, vocab2 in enumerate(masterVocabs):
        try:
            wiwjTuple1 = (vocab1, vocab2)
            wiwj = coOccuranceDict[wiwjTuple1]
            mij = np.log( (float(wiwj + 1.) * float(coOccuranceCardinality)) / \
                          (float(masterVocabCounts[i]) * float(masterVocabCounts[j])))
            dumList1.append(mij)
        except KeyError:
            wiwj = 0.
            mij = np.log( (float(wiwj + 1.) * float(coOccuranceCardinality)) / \
                          (float(masterVocabCounts[i]) * float(masterVocabCounts[j])))
            dumList1.append(mij)
    pmiMatrix.append(dumList1)

# %%
# Make the PMI Matrix a numpy array

pmiMatrix = np.array(pmiMatrix)

# cPickle it
cPickle.dump(np.array([pmiMatrix]), open("pmiMatrix.cp","wb"))

# %%
# Calculate SVD

U, s, V = scipy.sparse.linalg.svds(pmiMatrix, k=50)

# %%
# Calculate the W matrix
wMat = np.dot(np.array(U), np.power(np.diag(s), 1./2.))

# %%
# Save masterVocabCounts, masterVocabs and the W Matrix
cPickle.dump(masterVocabCounts, open("masterVocabCounts", "wb"))
cPickle.dump(masterVocabs, open("masterVocabs.cp", "wb"))
cPickle.dump(wMat, open("wMatrix.cp", "wb"))

# %% [markdown]
# # Part 4(a)

# %%
# Ran GloVe on midway to get wiki-vocab.txt and wiki-vectors.txt

vocab_file = 'GloVe/wiki-vocab.txt'
vectors_file = 'GloVe/wiki-vectors.txt'
with open(vocab_file, 'r') as f:
    words = [x.rstrip().split(' ')[0] for x in f.readlines()]
with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
        
vocab = {w: idx for idx, w in enumerate(words)}
ivocab = {idx: w for idx, w in enumerate(words)}

# %%
# What the embedding for umbrella looks like
vectors['umbrella']
# Out:
# [0.191622,
#  0.185738,
#  -0.385474,
#  -0.164728,
#  0.260358,
#  1.104398,
#  0.199163,
#  0.42758,
#  -0.382628,
#  -0.330602,
#  0.199798,
#  -0.713433,
#  -0.234381,
#  -0.023849,
#  0.285959,
#  -0.417093,
#  -0.092718,
#  -0.180878,
#  0.18382,
#  0.957654,
#  0.689498,
#  0.606767,
#  -0.636975,
#  0.173281,
#  0.342754,
#  -0.407437,
#  -0.806936,
#  -0.07333,
#  -0.253658,
#  0.620119,
#  -0.067735,
#  -0.635934,
#  -0.339229,
#  -0.631078,
#  -0.009188,
#  -0.43046,
#  -0.596538,
#  -0.037606,
#  0.589336,
#  0.549375,
#  0.235657,
#  -0.170194,
#  -0.629038,
#  -0.431413,
#  0.11747,
#  0.525274,
#  -0.009463,
#  0.239448,
#  0.04099,
#  0.365289]

# %% [markdown]
# # Part 4(b)

# %%
# For calculating the closest word, I'll be using sum of squared residuals as the metric
# This function will input the word of interest and the trained vector dictionary
# Output will be a list of tuples (word, residual)

def find_closest_word(word, vectors):
    wordResidualTuples = []
    wordVector = np.array(vectors[str(word)])
    for i in vectors:
        if str(i) == str(word):
            continue
        else:
            residual = np.sum((np.array(vectors[i]) - wordVector)**2)
            dumTuple = (i,residual)
            wordResidualTuples.append(dumTuple)
    return wordResidualTuples

# %%
# For wiki-trained GloVe set
vocab_file = 'GloVe/wiki-vocab.txt'
vectors_file = 'GloVe/wiki-vectors.txt'
with open(vocab_file, 'r') as f:
    words = [x.rstrip().split(' ')[0] for x in f.readlines()]
with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
        
vocab = {w: idx for idx, w in enumerate(words)}
ivocab = {idx: w for idx, w in enumerate(words)}

print "wiki-trained GloVe Set"
print "5 Words closest to physics:", sorted(find_closest_word('physics', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to republican:", sorted(find_closest_word('republican', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to einstein:", sorted(find_closest_word('einstein', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to algebra:", sorted(find_closest_word('algebra', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to fish:", sorted(find_closest_word('fish', vectors), key=lambda x:x[1])[:5]
# Out:
# wiki-trained GloVe Set
# 5 Words closest to physics: [('chemistry', 9.7493157640570001), ('mechanics', 10.926648474568001), ('mathematics', 11.097804873045), ('science', 11.559853958538001), ('quantum', 11.657098561397)]
# 5 Words closest to republican: [('democrat', 8.2856738879080005), ('senator', 8.3159226078849997), ('representative', 10.264810741461), ('whig', 14.943647567914002), ('democrats', 15.338086140509999)]
# 5 Words closest to einstein: [('relativity', 8.3924615954669992), ('maxwell', 9.3176571034650006), ('bose', 12.554689919525002), ('formulated', 12.730174469029), ('relates', 13.088836364464001)]
# 5 Words closest to algebra: [('algebras', 11.362341108321999), ('algebraic', 12.352666160467001), ('finite', 12.897992383249003), ('multiplication', 15.038205047775998), ('boolean', 15.098257696927998)]
# 5 Words closest to fish: [('feed', 9.4157081901660025), ('hunting', 11.752659976588999), ('fresh', 12.180701047149), ('bird', 12.490164597435999), ('salmon', 12.639436100863)]

# %%
# For pre-trained GloVe set

vectors_file = 'GloVe/glove.6B.50d.txt'

with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
        
print "pre-trained GloVe Set"
print "5 Words closest to physics:", sorted(find_closest_word('physics', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to republican:", sorted(find_closest_word('republican', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to einstein:", sorted(find_closest_word('einstein', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to algebra:", sorted(find_closest_word('algebra', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to fish:", sorted(find_closest_word('fish', vectors), key=lambda x:x[1])[:5]
# Out:
# pre-trained GloVe Set
# 5 Words closest to physics: [('chemistry', 6.7559904588019997), ('mathematics', 8.2927871603994401), ('theoretical', 10.117731250196), ('science', 11.498446593279693), ('biology', 12.18883092894624)]
# 5 Words closest to republican: [('gop', 3.2180613688839999), ('democrat', 6.5256713819699987), ('democratic', 6.8798670593370002), ('republicans', 6.9998712715300009), ('democrats', 7.1647835604499992)]
# 5 Words closest to einstein: [('bohr', 12.331782862801891), ('relativity', 13.194435220753251), ('invented', 13.358021733103), ('freud', 13.65192518977476), ('gottlieb', 13.742802154982)]
# 5 Words closest to algebra: [('geometry', 14.005960469049212), ('homological', 16.946830072610211), ('algebraic', 17.247541109883411), ('associative', 17.730630687553415), ('analytic', 18.863681267272412)]
# 5 Words closest to fish: [('salmon', 9.845436410973571), ('shrimp', 12.980046370305372), ('meat', 13.248687542532569), ('bird', 13.563175814569568), ('wild', 13.711795213364434)]

# %%
# For PMI Embedding set

vectors = {}
for i in range(len(wMat)):
    vectors[masterVocabs[i]] = wMat[i]

print "PMI Embedding Set"
print "5 Words closest to physics:", sorted(find_closest_word('physics', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to republican:", sorted(find_closest_word('republican', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to einstein:", sorted(find_closest_word('einstein', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to algebra:", sorted(find_closest_word('algebra', vectors), key=lambda x:x[1])[:5]
print "5 Words closest to fish:", sorted(find_closest_word('fish', vectors), key=lambda x:x[1])[:5]
# Out:
# PMI Embedding Set
# 5 Words closest to physics: [('mechanics', 1.8814189675199557), ('chemistry', 1.9798860739639306), ('quantum', 2.1829195572925015), ('mathematics', 2.2842540360565451), ('mathematical', 2.6082291783129374)]
# 5 Words closest to republican: [('senator', 1.6098700604002207), ('democrat', 1.6342500070534136), ('representative', 2.5541361292563658), ('democrats', 2.7024127301222265), ('candidate', 2.931239706363578)]
# 5 Words closest to einstein: [('relativity', 0.41794650119121945), ('paradox', 0.69473610063421221), ('maxwell', 0.7797152088885847), ('thesis', 0.8714555361643761), ('galileo', 0.95061625538847494)]
# 5 Words closest to algebra: [('algebraic', 0.52810908819007563), ('finite', 0.63136478549756514), ('theorem', 0.70716602247693672), ('equations', 0.91705211154669375), ('topology', 0.92368978319968598)]
# 5 Words closest to fish: [('fruit', 1.0377742952262106), ('meat', 1.5083024580696744), ('eggs', 1.7175448220733709), ('cattle', 1.7392827232077646), ('milk', 1.8796964901314361)]

# %% [markdown]
# ### Comment
# All the methodologies seems to produce some similar and different top 5 closest words in all cases. For example, for physics, wiki-glove found chemistry, mechanics, mathematics, science and quantum, pre-trained glove found chemistry, mathematics, theoretical, science, and biology, and PMI embedding found mechanics, chemistry, quantum, mathematics and mathematical. They all think chemistry and mathematics is quite related to each other, which makes sense because they are all different disciplines of sciences. However, at the same time, pre-trained glove is the only embedding with biology or theoretical listed as close to physics, and PMI embedding is the only one with mathematical in its list. This is quite similar in all other cases as well.

# %% [markdown]
# # Part 4(c): Analogies

# %% [markdown]
# france: paris :: england : ?

# %%
# Defining a way to calculate analogies
# Find a vector closest to v_?
# where v_? = v_paris - v_france + v_england or word1Partner - word1 + word2

def calc_analogy(word1, word1Partner, word2, vectors):
    try:
        wordVector1 = np.array(vectors[str(word1)])
        wordVector2 = np.array(vectors[str(word1Partner)])
        wordVector3 = np.array(vectors[str(word2)])
        predictVector = wordVector2 - wordVector1 + wordVector3
        oldResidual = 100000
        for i in vectors:
            residual = np.sum((np.array(vectors[i]) - predictVector)**2)
            if str(i) == str(word1) or str(i) == str(word1Partner) or str(i) == str(word2):
                continue
            else: 
                if residual < oldResidual:
                    oldResidual = residual
                    newWord = i
        return oldResidual, newWord
    except KeyError:
        print "Not in vocabulary"

# %%
# For PMI Embedding set

vectors = {}
for i in range(len(wMat)):
    vectors[masterVocabs[i]] = wMat[i]

calc_analogy('france','paris','england', vectors)
# Out:
# (3.249535102434344, 'london')

# %%
# For pre-trained GloVe set

vectors_file = 'GloVe/glove.6B.50d.txt'

with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
calc_analogy('france','paris','england', vectors)
# Out:
# (10.436077275769854, 'melbourne')

# %%
# For wiki-trained GloVe set
vocab_file = 'GloVe/wiki-vocab.txt'
vectors_file = 'GloVe/wiki-vectors.txt'
with open(vocab_file, 'r') as f:
    words = [x.rstrip().split(' ')[0] for x in f.readlines()]
with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
        
vocab = {w: idx for idx, w in enumerate(words)}
ivocab = {idx: w for idx, w in enumerate(words)}
calc_analogy('france','paris','england', vectors)
# Out:
# (8.5177800589740009, 'london')

# %% [markdown]
# ### Quick comment
# Interestingly, the pre-trained GloVe did the worst in this case. While PMI and wiki-trained GloVe set got london right, pre-trained GloVe got melbourne.

# %% [markdown]
# # Part 4(c)

# %%
import glob
import re

# For PMI Embedding set

vectors = {}
for i in range(len(wMat)):
    vectors[masterVocabs[i]] = wMat[i]

fileList = glob.glob('/project/cmsc25025/assn4_analogy/*.txt')
for i in fileList:
    for lines in open(i,'r'):
        lines = lines.strip()
        wordList = re.split('\\s+|:|=|\n|', lines)
        try:
            word1 = wordList[0]
            word2 = wordList[1]
            word3 = wordList[2]
            calc_analogy(word1, word2, word3, vectors)
        except IndexError:
            continue
# Out:
#  Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary
# Not in vocabulary

# %%
#For Pre-trained GloVE
vectors_file = 'GloVe/glove.6B.50d.txt'

with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]
        
fileList = glob.glob('/project/cmsc25025/assn4_analogy/*.txt')
for i in fileList:
    for lines in open(i,'r'):
        lines = lines.strip()
        wordList = re.split('\\s+|:|=|\n|', lines)
        try:
            word1 = wordList[0]
            word2 = wordList[1]
            word3 = wordList[2]
            print "%s:%s=%s:" % (word1, word2, word3), calc_analogy(word1, word2, word3, vectors)
        except IndexError:
            continue
# Out:
#  segregate:unify=damage: (22.216023051273886, 'overcome')
# argentina:brazil=iran: (17.45820330496753, 'tehran')
# ashes:urn=money: (15.991992414665587, 'cash')
# telephone:cord=television: (23.812014655449428, 'spinal')
# walk:roam=speak: (20.73361020644877, 'outsiders')
# novel:epilogue=meal: (16.754448878290621, 'multicourse')
# chinese:china=french: (3.1089572398459948, 'france')
# evening:morning=dinner: (6.5518783570198895, 'lunch')
# left:right=horizontal: (16.007326117333001, 'vertical')
# theorem:deduce=hypothesis: (18.106161431570616, 'clinicians')
# h:water=bird: (42.836569689659967, 'fish')
# chicken:egg=cow: (19.708530170798184, 'cloned')
# go:green=stop: (14.861276011043564, 'yellow')
# chicago:illinois=dallas: (5.1776843175535028, 'ohio')
# library:book=resturant: Not in vocabulary
# None
# dessert:meal=revelations: (17.90691484338863, 'abuse')
# chef:knife=student: (39.482594385490856, 'gun')
# cookies:milk=chips: (21.784270905250999, 'consumption')
# math:physics=calculus: (29.429075595307182, 'relativity')
# marvel:dc=captain: (21.466808954557589, 'adrian')
# thor:loki=hammer: (10.198517114715802, 'chopping')
# odin:hela=asgard: (18.536321665643939, 'stroma')
# beijing:shanghai=tiananmen: (19.403408714700003, 'pagoda')
# detroit:chicago=car: (11.678561916036049, 'driving')
# earth:mars=human: (16.192712532071962, 'cites')
# ice:fire=cold: (20.753326207928058, 'attack')
# lannister:stark=tywin: (11.804484997070812, 'suggests')
# uchicago:northwestern=smart: Not in vocabulary
# None
# physics:astronomy=chemistry: (13.219144078259001, 'egyptology')
# good:better=bad: (5.1365474921111831, 'worse')
# eat:happy=run: (19.535845111523582, 'career')
# healthy:vegetable=unhealthy: (23.130099282561488, 'perishable')
# rubber:elastic=glass: (23.621837191497931, 'three-dimensional')
# star:planet=nuclei: (35.646244735400003, 'atoms')
# night:black=day: (11.611601196004008, 'white')
# wolf:dog=tiger: (21.670419794832849, 'cat')
# canada:america=germany: (17.979882432878856, 'europe')
# china:tea=france: (30.418041945150303, 'champagne')
# left:right=up: (9.9709459856259794, 'make')
# dog:cat=puppy: (9.1893959770345788, 'kitten')
# finger:hand=toe: (11.884134276309291, 'heel')
# page:book=finger: (18.532441629227446, 'fingers')
# day:night=up: (7.3940439015935375, 'out')
# hard:easy=awake: (13.580019493489399, 'waking')
# brain:body=engine: (27.206443097666046, 'chassis')
# cereal:milk=butter: (22.670646465468089, 'mixture')
# street:city=vein: (22.121626089589338, 'hemispheres')
# happy:sad=smile: (16.633509941546091, 'pained')
# japan:sushi=mexico: (30.283627907863952, 'margaritas')
# economics:finance=mathematics: (13.588678828926851, 'scheme')
# basketball:jordan=soccer: (11.94957802503798, 'egypt')
# poetry:poet=music: (6.8398898281062497, 'musician')
# england:capitalism=china: (50.247135364001693, 'globalization')
# ship:sea=plane: (18.797221523014763, 'flies')
# physics:newton=biology: (15.026324103332882, 'addison')
# war:weapon=peace: (20.899868202187999, 'aim')
# school:teacher=hospital: (15.324541176942938, 'nurse')
# pork:pig=beef: (5.9166656160127964, 'cow')
# milwaukee:wisconsin=meridian: (23.201932927351443, 'cherwell')
# acting:oscar=music: (24.229709830509051, 'pop')
# present:past=contemporary: (19.920993488504731, 'inspired')
# judaism:rabbi=christianity: (14.988465940974837, 'isaac')
# tragedy:sad=comedy: (21.029017146175811, 'sitcom')
# ireland:potatoes=italy: (22.851291264918622, 'eggplant')
# sailing:boat=driving: (12.400386331997639, 'car')
# night:dark=day: (14.85225540865506, 'bright')
# motif:theme=detail: (17.625086845923168, 'attention')
# hypothesis:result=question: (19.306303014835578, 'because')
# black:color=triangle: (14.2592060957402, 'dimensional')
# cold:hot=freezing: (17.012857393173579, 'soak')
# cat:kitten=dog: (9.1893959770345788, 'puppy')
# france:europe=china: (23.466287100660455, 'taiwan')
# boy:girl=man: (3.8275003037281796, 'woman')
# tall:short=big: (28.18106982825989, 'making')
# master:apprentice=teacher: (10.902347027549609, 'schoolteacher')
# tree:plant=dog: (24.072858660880293, 'factory')
# knight:squire=professor: (14.15574562478459, 'sociologist')
# man:woman=mr: (5.668865981005899, 'mrs')
# democrat:republican=conservative: (9.5021008083337151, 'conservatives')
# guangdong:guangzhou=hangzhou: (16.508520482610237, 'wuhan')
# ohio:illinois=boston: (5.2690423925217047, 'chicago')
# senator:senate=representative: (9.6926590994405295, 'representatives')
# highway:car=railroad: (21.194078336055966, 'automobile')
# africa:congo=china: (15.634321299648441, 'vietnam')
# lincoln:republican=clinton: (23.88240610379609, 'democrats')
# computer:cpu=brain: (26.086863901222994, 'mitral')
# keyboard:hardware=linux: (33.1082064363897, 'open-source')
# physics:science=history: (21.229400719923582, 'nation')
# baseball:diamond=football: (18.020248216437004, 'diamonds')
# coffee:milk=toast: (15.879777820520001, 'butter')
# happy:sad=day: (14.115375224924179, 'days')
# dolphin:ocean=eagle: (19.156434151318255, 'atlantic')
# north:south=right: (8.9333463509720001, 'put')
# christian:church=muslim: (19.218589427301616, 'holy')
# pen:sword=love: (33.123144973814732, 'wicked')
# match:fire=hammer: (34.683427211975001, 'tank')
# happy:sad=wet: (18.003713666792404, 'foggy')
# heaven:god=hell: (14.719148151374984, 'evil')
# fire:burning=ice: (17.030233242040609, 'melting')
# boat:sink=car: (20.762630216933999, 'fix')
# three:four=five: (0.47579115984997006, 'six')
# woods:acorn=orchard: (28.526532803013687, 'casein')
# picture:blurry=knife: (18.616145618361845, 'slit')
# farm:dirt=city: (22.329491513052176, 'streets')
# drizzle:storm=wind: (35.537720994314313, 'hurricane')
# deer:doe=cow: (30.231413391524228, 'leaked')
# camera:picture=microphone: (12.90633815164246, 'nod')
# friend:enemy=cat: (26.936346194349209, 'predator')
# bose:einstein=newton: (25.068396506507913, 'lincoln')
# square:cube=triangle: (29.23186510368101, 'helix')
# linux:free=microsoft: (20.910282319339458, 'appeal')
# keyboard:type=mouse: (24.446683585955263, 'animal')
# coffee:bean=tea: (13.58503144727629, 'curry')
# michigan:lansing=illinois: (11.112424670138973, 'evanston')
# tree:bark=plant: (19.471142444129409, 'plants')
# hammer:nail=screwdriver: (17.625468449870478, 'scissors')
# dice:roll=coin: (29.591252839054398, 'stamp')
# mathematics:gauss=physics: (17.578872731811256, 'popper')
# boy:girl=man: (3.8275003037281796, 'woman')
# murder:suicide=knife: (21.766122552839537, 'bullet')
# dictionary:definition=novel: (20.367249023361367, 'reality')
# germany:hitler=china: (20.841908796213996, 'mao')
# listen:deaf=look: (17.081906758988303, 'transformed')
# beer:alcohol=marijuana: (33.206947572686516, 'drugs')
# america:canada=china: (16.436867951608409, 'taiwan')
# bread:butter=egg: (19.357801911664996, 'eggs')
# finance:money=technology: (26.453113893333555, 'ability')
# happy:smile=depressed: (16.06032487340476, 'pinched')
# tennis:racket=baseball: (29.513730429597494, 'throwing')
# Illinois:Springfield=Connecticut: Not in vocabulary
# None
# bed:sleep=chair: (19.098425125041931, 'hopkins')
# mango:fruit=eggplant: (13.214778886388421, 'cooked')
# pen:write=scissor: (29.454077335928542, 'compose')
# snake:reptile=frog: (14.205700126189001, 'amphibian')
# nose:breathe=eye: (20.643107591894495, 'someday')
# hand:finger=foot: (14.523230433648431, 'hoof')
# watch:wrist=ring: (21.985451117979448, 'forearm')
# girlfriend:wife=boyfriend: (3.2244147232960496, 'husband')
# pulse:heart=rhythm: (22.021259300841997, 'hip')
# sermons:priest=musicals: (26.078736122090646, 'dancer')
# therapy:psychologist=cuisine: (34.148436073478415, 'chef')
# silence:sounds=vacuum: (22.110319961344882, 'components')
# yin:daylight=yang: (14.354997745750339, 'stopping')
# documentation:governments=certification: (23.147057772846161, 'nations')
# taxonomy:biology=topology: (34.143456260775238, 'geometry')
# presidents:campaigns=generals: (15.53030995947657, 'tactics')
# prosecutor:accusations=defendant: (16.442064821492625, 'suspicion')
# marxist:capitalism=capitalist: (28.435389517271556, 'protectionism')
# steel:carnegie=computer: (35.3704054576069, 'science')
# art:artist=music: (10.35146270936225, 'singer')
# fruit:tomato=vegetable: (14.39337803932745, 'pasta')
# white:dwarf=gas: (23.605308316774998, 'liquefied')
# america:burger=italy: (26.831299422715436, 'maurizio')
# geography:land=statistics: (24.149435551100581, 'estimated')
# australia:sydney=france: (5.8439738368988055, 'paris')
# washington:redwood=japan: (24.123186795018523, 'icbc')
# good:friend=bad: (10.723588487536341, 'boyfriend')
# war:nuclear=peace: (30.778324222870001, 'enrichment')
# spain:spanish=poland: (3.8453578632468406, 'polish')
# string:guitar=key: (17.611101598079774, 'replacing')
# hot:cold=bright: (14.062697264594981, 'dark')
# happy:sad=positive: (14.289788991640346, 'alarming')
# elf:fair=dwarf: (22.96631638959953, 'places')
# dirt:brown=leaf: (33.071530179961997, 'grey')
# up:down=left: (7.1381815928028498, 'broke')
# hungry:eat=tired: (15.203108338910178, "'d")
# teacher:school=doctor: (14.221150167866202, 'where')
# eye:see=finger: (12.428350946372689, 'let')
# compactness:topology=differentiability: (24.832293814435246, 'differentiable')
# filibuster:holdup=gerrymandering: (27.933049963027191, 'vitez')
# miserly:generous=languid: (17.060066482648249, 'enjoys')
# happiness:ecstasy=unhappiness: (17.793813472003269, 'diclofenac')
# grape:fruit=tomato: (17.387003463071171, 'soup')
# sunrise:sunset=birth: (13.525201924808879, 'marriage')
# branch:tree=wheel: (30.655265416252, 'wheels')
# dance:dancer=swim: (12.85803390884, 'swam')
# chicago:illinois=houston: (7.0600463266278668, 'ohio')
# excitement:quench=fire: (25.531360347868269, 'extinguish')
# shoe:boot=shirt: (20.00330796039831, 'hat')
# talk:sing=walk: (27.274724670299566, 'amen')
# proletariet:bourgeois=man: Not in vocabulary
# None
# baby:adult=puppy: (17.199831718702086, 'generalist')
# novice:master=amateur: (19.347126597965957, 'professional')
# short:tall=skinny: (25.410367628101667, 'wiry')
# thank:apologize=greet: (11.398791559226531, 'infuriated')
# cow:herd=bird: (15.990916307121001, 'elephants')
# basketball:court=football: (14.59433065125727, 'appeals')
# student:teacher=employee: (9.3081711253219588, 'employer')
# illinois:chicago=california: (9.9310810465007133, 'angeles')
# russia:putin=germany: (8.0588043236881504, 'kohl')
# microsoft:windows=apple: (20.864444027818813, 'window')
# federer:tennis=ronaldo: (17.633914690644371, 'soccer')
# sushi:japan=lasagna: (20.837656917576002, 'greece')
# fish:water=bird: (16.480450931708809, 'cloud')
# black:white=dark: (11.05375249725137, 'gray')
# eyes:ears=see: (10.274940056854401, 'probably')
# firefighter:fire=doctor: (16.138189895556003, 'taken')
# north:south=east: (5.4614297097889999, 'west')
# methane:methanol=ethane: (14.243451720856852, 'b20')
# past:future=behind: (10.703754968102881, 'challenge')
# rusnok:czechia=singh: (25.313475395589414, 'cha')
# fermion:electron=boson: (45.262091802560441, 'jupiter')
# apple:us=huawei: (32.368332856551611, 'militaries')
# sociology:soft=physics: (17.478878615301362, 'liquid')
# key:lock=password: (31.65149824123149, 'username')
# aristotle:plato=plato: (18.75740268137265, 'cratylus')
# Australia:act=us: Not in vocabulary
# None
# mexico:taco=china: (21.695935753362619, 'kfc')
# boy:girl=man: (3.8275003037281796, 'woman')
# russia:moscow=china: (4.5398660787474903, 'beijing')
# hospital:nurse=school: (15.324541176942938, 'teacher')
# kitten:cat=puppy: (9.1893959770345788, 'dog')
# breakfast:morning=dinner: (6.8885977698074088, 'afternoon')
# movie:watch=book: (14.272458586046582, 'read')
# comedy:funny=tragedy: (16.510208982502999, 'terrible')
# english:england=russian: (13.839216802585142, 'russia')
# fraternity:male=sorority: (9.2213897179208892, 'female')
# left:right=up: (9.9709459856259794, 'make')
# olympia:washington=annapolis: (32.329454777635483, 'discuss')
# breakfast:morning=dinner: (6.8885977698074088, 'afternoon')
# pen:writing=brush: (22.083642335932645, 'work')
# basketball:hoop=soccer: (17.487490055326887, 'scheffer')
# baltimore:ravens=pittsburgh: (5.0916860193833289, 'steelers')
# coffee:mug=soup: (18.186442640724998, ':-)')
# eggs:omelette=flour: (20.038847655143183, 'semolina')
# santa:christmas=bunny: (38.559657948142672, 'halloween')
# economics:money=theology: (24.11727040451116, 'proceeds')
# sit:chair=sleep: (17.514697559022, 'therapist')
# open:closed=near: (21.032782596068159, 'nearby')
# smart:intelligent=sly: (11.704831277656179, 'playful')
# mouth:eat=ear: (16.082170905902615, 'ate')
# dirt:brown=leaves: (35.987629957503003, 'white')
# summer:hot=winter: (11.234637357532053, 'snow')
# nurse:hospital=teacher: (15.324541176942938, 'school')
# thirsty:drink=hungry: (13.441632021094, 'drinks')
# up:down=left: (7.1381815928028498, 'broke')
# pencil:write=knife: (17.527661654578182, 'parents')
# bed:bedroom=toilet: (11.162341645364812, 'bathroom')
# sonny:cher=simon: (18.880492808973496, 'garfunkel')
# quayle:bush=gore: (14.492711801606761, 'clinton')
# laurel:hardy=cheech: (25.151641537284323, 'fickman')
# batman:gotham=superman: (10.30690340391995, 'excalibur')
# pork:pig=beef: (5.9166656160127964, 'cow')
# crow:murder=lion: (22.635241156738651, 'robbery')
# left:right=up: (9.9709459856259794, 'make')
# paris:parisian=glasgow: (17.603979819347771, 'romford')
# manicure:fingers=pedicure: (7.6886338216479997, 'toes')
# austin:texas=topeka: (17.814283526172051, 'wichita')
# fruit:juice=milk: (14.302734204908612, 'soda')
# animal:zoo=plant: (31.909569622358006, 'facility')
# england:london=china: (19.718255316038501, 'beijing')
# lip:lipstick=eye: (15.805665175674299, 'mask')
# restaurant:food=bar: (15.131069737590296, 'reduce')
# winter:ski=summer: (14.550640441262797, 'golf')
# weekday:work=weekend: (26.357262635499154, 'effort')
# hospital:doctor=school: (15.8074886261993, 'taught')
# bank:money=museum: (27.542874300367682, 'collection')
# back:deadlift=legs: (27.37270858032073, 'chitinous')
# sun:day=moon: (19.441463924917525, 'eve')
# cow:beef=pig: (5.9166656160127964, 'pork')
# woman:man=girl: (3.8275003037281796, 'boy')
# homeless:poor=billionaire: (25.255249139433687, 'tycoon')
# baby:adult=puppy: (17.199831718702086, 'generalist')
# fish:swimming=bird: (17.354475465310568, 'olympic')
# fire:hot=ice: (37.553057290986153, 'cream')
# mouth:speak=hand: (23.38107108269363, 'wanted')
# china:asia=france: (21.47233200223085, 'belgium')
# in:out=up: (15.503969906584928, 'down')
# canada:ontario=england: (11.34861944496909, 'sussex')
# congress:congressman=senate: (14.244202101935242, 'sen.')
# congressman:election=senator: (11.05670954754488, 'elections')
# doctor:patient=pilot: (16.430728441990691, 'pilots')
# china:chinese=england: (11.452100336244381, 'scottish')
# china:chinese=canada: (4.7097992041571795, 'canadian')
# white:black=bright: (11.393277350288411, 'dark')
# white:color=black: (11.1011316712985, 'colors')
# poker:tournament=football: (25.953264610674424, 'team')
# bark:dog=meow: (36.65303562220722, 'bash')
# good:heaven=evil: (28.928824584349378, 'daleks')
# drop:rain=flake: (30.080184336002002, 'salukvadze')
# leaf:tree=petal: (21.241977829995999, 'syringa')
# finger:hand=toe: (11.884134276309291, 'heel')
# calf:cow=lamb: (16.152418664978651, 'meat')
# moon:night=sun: (20.077420887851208, 'morning')
# hoof:horse=foot: (25.840922028164382, 'ride')
# hot:summer=cold: (11.395577240498048, 'winter')
# electron:atom=planet: (29.515084967690843, 'universe')
# summer:hot=winter: (11.234637357532053, 'snow')
# english:words=math: (31.598537406635494, 'memorize')
# tshirt:top=pants: Not in vocabulary
# None
# eye:see=ear: (8.6290745337139114, 'whenever')
# hate:love=darkness: (24.897919497758661, 'twilight')
# hill:mountain=lake: (19.124753148755637, 'lakes')
# light:lamp=wind: (14.629090522029326, 'furnace')
# cloud:rain=sun: (27.597629835504002, 'afternoon')
# tv:watch=book: (21.116746678644358, 'read')
# jew:judaism=christian: (22.147212430516621, 'christianity')
# chicago:beijing=windy: (38.170581604737961, 'bumpy')
# humanities:unemployed=science: (19.214690776917561, 'seriously')
# finance:evil=academia: (38.399807476281289, 'incarnate')
# school:stress=vacation: (29.870546035068095, 'unforeseen')
# cow:pig=beef: (5.9166656160127955, 'pork')
# cow:beef=pig: (5.9166656160127964, 'pork')
# beer:alcohol=weed: (24.555075232886043, 'offenders')
# banker:powerpoint=engineer: (26.708077416806923, 'computer-based')
# class:studying=gym: (24.813083378157522, 'lab')
# machine:learning=human: (27.921012947793244, 'understanding')
# father:doctor=mother: (9.3083243638156503, 'nurse')
# man:programmer=woman: (13.460482338948593, 'prodigy')
# dog:bark=cat: (13.140006706565291, 'twigs')
# chicken:eggs=humans: (27.60350548111369, 'organisms')
# shard:pottery=splinter: (41.238713011414262, 'groups')
# chicago:illinois=milwaukee: (8.2198589541795055, 'ohio')
# stars:cosmos=dirt: (24.675442141113681, 'hydrant')
# eraser:pencil=hat: (17.662313459558419, 'shirt')
# christmas:december=halloween: (9.2268723583710912, 'november')
# hitler:germany=stalin: (11.951270247862002, 'austria')

# %%
# For wiki-trained GloVe set
vocab_file = 'GloVe/wiki-vocab.txt'
vectors_file = 'GloVe/wiki-vectors.txt'
with open(vocab_file, 'r') as f:
    words = [x.rstrip().split(' ')[0] for x in f.readlines()]
with open(vectors_file, 'r') as f:
    vectors = {}
    for line in f:
        vals = line.rstrip().split(' ')
        vectors[vals[0]] = [float(x) for x in vals[1:]]

fileList = glob.glob('/project/cmsc25025/assn4_analogy/*.txt')
for i in fileList:
    for lines in open(i,'r'):
        lines = lines.strip()
        wordList = re.split('\\s+|:|=|\n|', lines)
        try:
            word1 = wordList[0]
            word2 = wordList[1]
            word3 = wordList[2]
            print "%s:%s=%s:" % (word1, word2, word3), calc_analogy(word1, word2, word3, vectors)
        except IndexError:
            continue
# Out:
# segregate:unify=damage: Not in vocabulary
# None
# argentina:brazil=iran: (12.481233426906, 'pakistan')
# ashes:urn=money: (17.897226898940996, 'gift')
# telephone:cord=television: (27.990478267321006, 'starred')
# walk:roam=speak: (24.912176597150999, 'pakistanis')
# novel:epilogue=meal: (27.269514285765005, 'meals')
# chinese:china=french: (8.0161522676669996, 'france')
# evening:morning=dinner: (8.9159369607800016, 'lunch')
# left:right=horizontal: (10.839459601949001, 'vertical')
# theorem:deduce=hypothesis: (18.417008727633998, 'anticipate')
# h:water=bird: (38.709419627384001, 'fresh')
# chicken:egg=cow: (16.184230683614999, 'wreck')
# go:green=stop: (13.619416007029999, 'red')
# chicago:illinois=dallas: (11.265640445845001, 'iowa')
# library:book=resturant: Not in vocabulary
# None
# dessert:meal=revelations: (23.724251426663997, 'prophecy')
# chef:knife=student: (18.557168143024999, 'students')
# cookies:milk=chips: (18.48991522399, 'sugar')
# math:physics=calculus: (18.092897097425002, 'mechanics')
# marvel:dc=captain: (14.816557121139999, 'lieutenant')
# thor:loki=hammer: (12.957246231561001, 'trick')
# odin:hela=asgard: (15.087099619543, 'overlays')
# beijing:shanghai=tiananmen: (13.878547052449001, 'crackdown')
# detroit:chicago=car: (14.957399034659, 'cars')
# earth:mars=human: (16.697862552270003, 'animal')
# ice:fire=cold: (22.476988465653001, 'attacks')
# lannister:stark=tywin: Not in vocabulary
# None
# uchicago:northwestern=smart: Not in vocabulary
# None
# physics:astronomy=chemistry: (12.436007678457001, 'biochemistry')
# good:better=bad: (6.8576730416949996, 'worse')
# eat:happy=run: (21.70647271827, 'running')
# healthy:vegetable=unhealthy: (14.029311029125999, 'garlic')
# rubber:elastic=glass: (21.180424523573002, 'convection')
# star:planet=nuclei: (18.646226336278996, 'nucleus')
# night:black=day: (14.350357890344, 'white')
# wolf:dog=tiger: (13.377440020834001, 'breed')
# canada:america=germany: (20.463272068698998, 'europe')
# china:tea=france: (24.987246096959996, 'toast')
# left:right=up: (9.1657790238239993, 'out')
# dog:cat=puppy: (8.4972867178870004, 'blob')
# finger:hand=toe: (16.019299043194998, 'pick')
# page:book=finger: (23.336654979997999, 'passion')
# day:night=up: (13.642928056411003, 'away')
# hard:easy=awake: (14.269217394468999, 'depart')
# brain:body=engine: (21.409058885323002, 'engines')
# cereal:milk=butter: (27.132137814625004, 'chocolate')
# street:city=vein: (22.396809298087003, 'drains')
# happy:sad=smile: (14.533015757016999, 'bydgoszcz')
# japan:sushi=mexico: (20.244494351827996, 'pottawatomie')
# economics:finance=mathematics: (15.869578313243997, 'searching')
# basketball:jordan=soccer: (15.269897857467004, 'norway')
# poetry:poet=music: (13.793685607953, 'composer')
# england:capitalism=china: (40.221388936373998, 'socialism')
# ship:sea=plane: (17.060450325697001, 'equator')
# physics:newton=biology: (12.743081771462, 'tilton')
# war:weapon=peace: (15.746377404862001, 'healing')
# school:teacher=hospital: (13.297523839247001, 'surgeon')
# pork:pig=beef: (11.623494209123999, 'rat')
# milwaukee:wisconsin=meridian: (21.087619552713001, 'franklin')
# acting:oscar=music: (23.133714640828, 'musical')
# present:past=contemporary: (13.268972061784002, 'literary')
# judaism:rabbi=christianity: (10.740290692312, 'jacob')
# tragedy:sad=comedy: (18.995124437200001, 'tonight')
# ireland:potatoes=italy: (29.788063612366006, 'beans')
# sailing:boat=driving: (11.244539824103002, 'car')
# night:dark=day: (12.176157881285, 'comes')
# motif:theme=detail: (15.357661232411999, 'details')
# hypothesis:result=question: (14.676904063817, 'without')
# black:color=triangle: (20.753201208730999, 'pixel')
# cold:hot=freezing: (14.853618988275, 'snow')
# cat:kitten=dog: (16.458515738911998, 'shepherd')
# france:europe=china: (18.482353723443001, 'asia')
# boy:girl=man: (6.0456097707849992, 'woman')
# tall:short=big: (22.397798685760002, 'movie')
# master:apprentice=teacher: (8.8621598085809996, 'teenager')
# tree:plant=dog: (21.591965745642, 'dogs')
# knight:squire=professor: (17.042005504141994, 'emeritus')
# man:woman=mr: (6.9797345983320005, 'mrs')
# democrat:republican=conservative: (14.926557042716004, 'liberal')
# guangdong:guangzhou=hangzhou: (16.686518009681997, 'shanghai')
# ohio:illinois=boston: (7.3097473868090006, 'chicago')
# senator:senate=representative: (8.7424484229810009, 'assembly')
# highway:car=railroad: (16.644102331559001, 'automobile')
# africa:congo=china: (15.8574521069, 'chen')
# lincoln:republican=clinton: (13.259165463913002, 'senator')
# computer:cpu=brain: (25.493986942324, 'abdominal')
# keyboard:hardware=linux: (27.625107989345, 'os')
# physics:science=history: (18.732842853815999, 'historical')
# baseball:diamond=football: (13.142964472905, 'crystal')
# coffee:milk=toast: (17.375622173522, 'stains')
# happy:sad=day: (12.809841101650999, 'present')
# dolphin:ocean=eagle: (26.468272140900002, 'sea')
# north:south=right: (10.113414108192998, 'left')
# christian:church=muslim: (13.917853633038, 'muslims')
# pen:sword=love: (34.815374994049002, 'soul')
# match:fire=hammer: (26.032071893695999, 'burning')
# happy:sad=wet: (16.366612210587, 'damp')
# heaven:god=hell: (13.282341373735001, 'divine')
# fire:burning=ice: (14.836881283497998, 'melt')
# boat:sink=car: (14.366292618239001, 'drives')
# three:four=five: (0.6635937645390001, 'six')
# woods:acorn=orchard: (18.897356235844999, 'archimedes')
# picture:blurry=knife: (21.330769723656992, 'twig')
# farm:dirt=city: (17.642867615431999, 'downtown')
# drizzle:storm=wind: Not in vocabulary
# None
# deer:doe=cow: (20.344093040290002, 'blige')
# camera:picture=microphone: (15.009324827355, 'fills')
# friend:enemy=cat: (28.489592534289006, 'flying')
# bose:einstein=newton: (17.355511123517999, 'maxwell')
# square:cube=triangle: (16.496844678098, 'commutator')
# linux:free=microsoft: (18.785704107087998, 'instead')
# keyboard:type=mouse: (20.870643949083, 'giant')
# coffee:bean=tea: (15.465800408504998, 'ruddy')
# michigan:lansing=illinois: (10.825716447731001, 'tulsa')
# tree:bark=plant: (20.752863921255003, 'sewage')
# hammer:nail=screwdriver: (17.744241437863, 'earthenware')
# dice:roll=coin: (22.654280860052999, 'coinage')
# mathematics:gauss=physics: (17.085448545031003, 'einstein')
# boy:girl=man: (6.0456097707849992, 'woman')
# murder:suicide=knife: (12.816829216357997, 'blades')
# dictionary:definition=novel: (25.370490539456, 'plot')
# germany:hitler=china: (14.371927181227999, 'mao')
# listen:deaf=look: (19.928081484778001, 'confused')
# beer:alcohol=marijuana: (20.534028916084996, 'drug')
# america:canada=china: (14.065599342765998, 'taiwan')
# bread:butter=egg: (18.6908357535, 'eggs')
# finance:money=technology: (20.617138779322001, 'because')
# happy:smile=depressed: (11.469699008392999, 'gripped')
# tennis:racket=baseball: (13.968977357392001, 'sox')
# Illinois:Springfield=Connecticut: Not in vocabulary
# None
# bed:sleep=chair: (17.552188494960003, 'faculty')
# mango:fruit=eggplant: (16.753058147810002, 'flowers')
# pen:write=scissor: (23.756766596524002, 'multiply')
# snake:reptile=frog: (15.025186265111001, 'namesakes')
# nose:breathe=eye: (16.8444101748, 'vision')
# hand:finger=foot: (13.036225847539001, 'aft')
# watch:wrist=ring: (23.271403290700999, 'finger')
# girlfriend:wife=boyfriend: (6.8027813932949996, 'father')
# pulse:heart=rhythm: (28.033215503750998, 'lead')
# sermons:priest=musicals: (15.785094988316999, 'dancer')
# therapy:psychologist=cuisine: (32.980963020285003, 'andalusian')
# silence:sounds=vacuum: (24.679544689620005, 'mechanical')
# yin:daylight=yang: (11.282549194114001, 'midnight')
# documentation:governments=certification: (20.163434123959, 'unions')
# taxonomy:biology=topology: (24.222677387512999, 'mathematics')
# presidents:campaigns=generals: (21.166635206477999, 'armies')
# prosecutor:accusations=defendant: (17.196528115243002, 'outright')
# marxist:capitalism=capitalist: (29.253260562361003, 'markets')
# steel:carnegie=computer: (32.962327391843999, 'computing')
# art:artist=music: (13.138844860713, 'pop')
# fruit:tomato=vegetable: (13.770911086273001, 'macaroni')
# white:dwarf=gas: (25.373961391504999, 'antimatter')
# america:burger=italy: (21.783388492732001, 'ferrara')
# geography:land=statistics: (20.809514492651999, 'collect')
# australia:sydney=france: (6.9300109563619996, 'paris')
# washington:redwood=japan: (26.112267639135002, 'cantopop')
# good:friend=bad: (12.338403040066998, 'uncle')
# war:nuclear=peace: (24.413908201606997, 'disarmament')
# spain:spanish=poland: (4.0788482444999996, 'polish')
# string:guitar=key: (14.640780445411, 'steve')
# hot:cold=bright: (16.495261530099999, 'seeing')
# happy:sad=positive: (14.303298949278997, 'negative')
# elf:fair=dwarf: (17.769531596358998, 'bird')
# dirt:brown=leaf: (35.416282645004998, 'red')
# up:down=left: (10.219074103617, 'right')
# hungry:eat=tired: (12.784898025326001, 'eaten')
# teacher:school=doctor: (17.550173877414, 'college')
# eye:see=finger: (19.530639202561005, 'table')
# compactness:topology=differentiability: Not in vocabulary
# None
# filibuster:holdup=gerrymandering: Not in vocabulary
# None
# miserly:generous=languid: Not in vocabulary
# None
# happiness:ecstasy=unhappiness: (10.314266374379001, 'mdma')
# grape:fruit=tomato: (15.452699406897002, 'leaves')
# sunrise:sunset=birth: (12.363098670336001, 'death')
# branch:tree=wheel: (30.915379656793998, 'spinning')
# dance:dancer=swim: (22.280530788898002, 'lola')
# chicago:illinois=houston: (9.5551812512810006, 'iowa')
# excitement:quench=fire: Not in vocabulary
# None
# shoe:boot=shirt: (17.382621433131003, 'patches')
# talk:sing=walk: (30.938048362113999, 'sang')
# proletariet:bourgeois=man: Not in vocabulary
# None
# baby:adult=puppy: (16.47630035417, 'secretive')
# novice:master=amateur: (21.015469042422001, 'first')
# short:tall=skinny: (24.194669413735003, 'mouthed')
# thank:apologize=greet: (11.611739770501, 'humiliate')
# cow:herd=bird: (15.873510500737, 'birds')
# basketball:court=football: (18.073993112827999, 'courts')
# student:teacher=employee: (13.350294342184998, 'dentist')
# illinois:chicago=california: (12.554218706295002, 'los')
# russia:putin=germany: (12.614208478163, 'hitler')
# microsoft:windows=apple: (15.638884999677, 'mac')
# federer:tennis=ronaldo: (22.292415499844996, 'soccer')
# sushi:japan=lasagna: Not in vocabulary
# None
# fish:water=bird: (17.323457356824001, 'covered')
# black:white=dark: (11.251814572395999, 'bright')
# eyes:ears=see: (11.383645987484, 'refer')
# firefighter:fire=doctor: (22.77449049474, 'before')
# north:south=east: (3.3465340603909999, 'west')
# methane:methanol=ethane: (8.0002159244190008, 'acetone')
# past:future=behind: (10.124357934821999, 'another')
# rusnok:czechia=singh: Not in vocabulary
# None
# fermion:electron=boson: (24.903293052738999, 'electrons')
# apple:us=huawei: Not in vocabulary
# None
# sociology:soft=physics: (26.464970013504999, 'liquid')
# key:lock=password: (17.134344089600003, 'suck')
# aristotle:plato=plato: (13.628705212461, 'socrates')
# Australia:act=us: Not in vocabulary
# None
# mexico:taco=china: (20.150479469124999, 'kitchen')
# boy:girl=man: (6.0456097707849992, 'woman')
# russia:moscow=china: (7.6602794071120011, 'beijing')
# hospital:nurse=school: (16.577525093197998, 'graduate')
# kitten:cat=puppy: (17.111530610388002, 'rabbit')
# breakfast:morning=dinner: (10.210291981699001, 'evening')
# movie:watch=book: (15.348643996723, 'bible')
# comedy:funny=tragedy: (16.433159002875001, 'mistake')
# english:england=russian: (12.697545271216001, 'russia')
# fraternity:male=sorority: (11.462438467186001, 'female')
# left:right=up: (9.1657790238239993, 'out')
# olympia:washington=annapolis: (21.807126919272001, 'virginia')
# breakfast:morning=dinner: (10.210291981699001, 'evening')
# pen:writing=brush: (16.161767213786998, 'reading')
# basketball:hoop=soccer: (16.870157424169001, 'hula')
# baltimore:ravens=pittsburgh: (12.062723280575002, 'patriots')
# coffee:mug=soup: (17.966656954607004, 'twinkie')
# eggs:omelette=flour: (25.436229869275003, 'tortilla')
# santa:christmas=bunny: (44.845756772868995, 'sitcom')
# economics:money=theology: (16.955049055749999, 'faith')
# sit:chair=sleep: (20.311276178012999, 'meteorology')
# open:closed=near: (19.147538004831997, 'nearby')
# smart:intelligent=sly: (16.547900464027997, 'intellect')
# mouth:eat=ear: (16.239425992481998, 'eats')
# dirt:brown=leaves: (32.841249061199996, 'red')
# summer:hot=winter: (9.8599387522620017, 'cold')
# nurse:hospital=teacher: (17.795897607095, 'school')
# thirsty:drink=hungry: (17.104989809092999, 'beer')
# up:down=left: (10.219074103617, 'right')
# pencil:write=knife: (20.993396220769, 'call')
# bed:bedroom=toilet: (20.122551162803997, 'nubus')
# sonny:cher=simon: (17.289133979318002, 'michel')
# quayle:bush=gore: (19.162866259274999, 'clinton')
# laurel:hardy=cheech: (16.441312940930001, 'gino')
# batman:gotham=superman: (10.951099418804999, 'bacolod')
# pork:pig=beef: (11.623494209123999, 'rat')
# crow:murder=lion: (29.823642417748001, 'death')
# left:right=up: (9.1657790238239993, 'out')
# paris:parisian=glasgow: (23.152300109702001, 'glaswegians')
# manicure:fingers=pedicure: Not in vocabulary
# None
# austin:texas=topeka: (20.041793960387, 'atchison')
# fruit:juice=milk: (16.867675638682002, 'drinks')
# animal:zoo=plant: (24.239721918092997, 'kathmandu')
# england:london=china: (17.459635077650997, 'beijing')
# lip:lipstick=eye: (19.666223016657, 'vision')
# restaurant:food=bar: (16.263343460244002, 'produce')
# winter:ski=summer: (15.934956682552, 'surf')
# weekday:work=weekend: (16.528153782020997, 'works')
# hospital:doctor=school: (19.574369925886, 'master')
# bank:money=museum: (17.379755921163998, 'art')
# back:deadlift=legs: Not in vocabulary
# None
# sun:day=moon: (17.278693734146998, 'days')
# cow:beef=pig: (13.029929786472, 'pork')
# woman:man=girl: (6.0456097707850001, 'boy')
# homeless:poor=billionaire: (14.879395959302999, 'businessman')
# baby:adult=puppy: (16.47630035417, 'secretive')
# fish:swimming=bird: (17.806449023031, 'gymnastics')
# fire:hot=ice: (29.233881616083, 'wet')
# mouth:speak=hand: (18.545517648705996, 'choose')
# china:asia=france: (18.482353723442998, 'europe')
# in:out=up: (14.447937735258, 'down')
# canada:ontario=england: (14.743475740094, 'yorkshire')
# congress:congressman=senate: (17.575677719759998, 'senator')
# congressman:election=senator: (21.996353512409001, 'elections')
# doctor:patient=pilot: (21.804361722031, 'target')
# china:chinese=england: (14.847597863737001, 'scottish')
# china:chinese=canada: (9.8165986475800011, 'canadian')
# white:black=bright: (10.068880169342002, 'shining')
# white:color=black: (7.3339294977310008, 'colour')
# poker:tournament=football: (18.304634395077997, 'league')
# bark:dog=meow: (33.623845029141009, 'dutchman')
# good:heaven=evil: (21.131193987315999, 'hell')
# drop:rain=flake: (13.514893147595002, 'raya')
# leaf:tree=petal: (17.448721278618997, 'cob')
# finger:hand=toe: (16.019299043194998, 'pick')
# calf:cow=lamb: (20.295073681987997, 'doe')
# moon:night=sun: (12.854690278348997, 'morning')
# hoof:horse=foot: (25.808356452692998, 'feet')
# hot:summer=cold: (9.8599387522620017, 'winter')
# electron:atom=planet: (18.905359362583003, 'trilogy')
# summer:hot=winter: (9.8599387522620017, 'cold')
# english:words=math: (20.929665760677999, 'predicates')
# tshirt:top=pants: Not in vocabulary
# None
# eye:see=ear: (12.743085016562, 'refer')
# hate:love=darkness: (20.528959210084, 'glory')
# hill:mountain=lake: (16.559485699207002, 'mountains')
# light:lamp=wind: (17.568580279004998, 'cooker')
# cloud:rain=sun: (24.099659802798001, 'midnight')
# tv:watch=book: (20.947117091891002, 'account')
# jew:judaism=christian: (25.096549999569, 'christianity')
# chicago:beijing=windy: (28.088492365034003, 'vientiane')
# humanities:unemployed=science: (12.394870084168002, 'working')
# finance:evil=academia: (25.396564361122, 'immortal')
# school:stress=vacation: (27.323722109309998, 'mitigating')
# cow:pig=beef: (13.029929786471998, 'pork')
# cow:beef=pig: (13.029929786472, 'pork')
# beer:alcohol=weed: (21.683523306134994, 'invasive')
# banker:powerpoint=engineer: (26.698468343613001, 'mixing')
# class:studying=gym: (29.886425087235999, 'milken')
# machine:learning=human: (24.808811859072001, 'studies')
# father:doctor=mother: (14.711105220939, 'adult')
# man:programmer=woman: (14.159912864108998, 'novice')
# dog:bark=cat: (17.727560667407001, 'twigs')
# chicken:eggs=humans: (20.661613447928001, 'organisms')
# shard:pottery=splinter: (32.032898206870001, 'evolved')
# chicago:illinois=milwaukee: (10.666732941866002, 'iowa')
# stars:cosmos=dirt: (25.630557104733001, 'loi')
# eraser:pencil=hat: (25.401989690259001, 'trick')
# christmas:december=halloween: (14.098433090511, 'october')
# hitler:germany=stalin: (9.2621402575559983, 'russia')

# %% [markdown]
# ## Comment
# It seems like the PMI Embedding somehow lacks lot of the vocabularies used in the posted analogies. PMI embeddings couldn't get any of the analogies because it couldn't find at least one of the words used in the analogies. However, for wiki- and pre-trained GloVe, the methodologies do decently well in predicting the right word. For example, an easy one like boy:girl=man:woman. However, on some of the harder analogies, both seem to fail. For pre-trained, walk:roam=speak: (20.73361020644877, 'outsiders') and for wiki-trained, walk:roam=speak: (24.912176597150999, 'pakistanis'). Regardless, it is quite impressive that they can get the right words in many cases!

# %% [markdown]
# # Part 4(d)

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib notebook
# For pre-trained GloVe set

vectors_file = 'GloVe/glove.6B.50d.txt'

with open(vectors_file, 'r') as f:
    vectors = []
    words = []
    for line in f:
        vals = line.rstrip().split(' ')
        words.append(str(vals[0]))
        vectors.append([float(x) for x in vals[1:]])

# %%
vectors = np.array(vectors)
for label, x, y in zip(words[:1000], Y[:, 0], Y[:, 1]):
    print label, x, y
    break
# Out:
# the -4.65691470989 -9.07526740308

# %%
tsne = TSNE(n_components=2, random_state=0)
np.set_printoptions(suppress=True)
Y = tsne.fit_transform(vectors[:1000,:])
plt.figure(figsize=(8,8))
plt.scatter(Y[:, 0], Y[:, 1])
for label, x, y in zip(words[:1000], Y[:, 0], Y[:, 1]):
    plt.annotate(label.decode('utf-8'), xy=(x, y), xytext=(0, 0), textcoords='offset points', fontsize=10)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# ### Comment
#
# I found a cluster of the months in a year.
